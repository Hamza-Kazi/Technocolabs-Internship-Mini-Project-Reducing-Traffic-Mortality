# %% [markdown]
# Loading libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Data

# %%
df_1 = pd.read_csv(r"C:\Users\Hamza\OneDrive\Desktop\Technocolabs Internship\Project 1\miles-driven.csv")
df_2 = pd.read_csv(r"C:\Users\Hamza\OneDrive\Desktop\Technocolabs Internship\Project 1\road-accidents.csv")

# %% [markdown]
# Checking data structure

# %%
df_2.shape
# Out:
# (60, 1)

# %%
df_2.head(10)
# Out:
#                                  ##### LICENSE #####
# 0  # This data set is modified from the original ...
# 1  # and it is released under CC BY 4.0 (https://...
# 2                   ##### COLUMN ABBREVIATIONS #####
# 3  # drvr_fatl_col_bmiles = Number of drivers inv...
# 4  # perc_fatl_speed = Percentage Of Drivers Invo...
# 5  # perc_fatl_alcohol = Percentage Of Drivers In...
# 6  # perc_fatl_1st_time = Percentage Of Drivers I...
# 7                             ##### DATA BEGIN #####
# 8  state|drvr_fatl_col_bmiles|perc_fatl_speed|per...
# 9                              Alabama|18.8|39|30|80

# %% [markdown]
# Data Cleaning and Preprocessing

# %%
df_2[['State','fatl_col_bmiles','perc_fatl_speed','perc_fatl_alcohol','perc_fatl_1st_time']] = df_2['##### LICENSE #####'].str.split('|',expand=True)
df_2
# Out:
#                                   ##### LICENSE #####  \
# 0   # This data set is modified from the original ...
# 1   # and it is released under CC BY 4.0 (https://...
# 2                    ##### COLUMN ABBREVIATIONS #####
# 3   # drvr_fatl_col_bmiles = Number of drivers inv...
# 4   # perc_fatl_speed = Percentage Of Drivers Invo...
# 5   # perc_fatl_alcohol = Percentage Of Drivers In...
# 6   # perc_fatl_1st_time = Percentage Of Drivers I...
# 7                              ##### DATA BEGIN #####
# 8   state|drvr_fatl_col_bmiles|perc_fatl_speed|per...
# 9                               Alabama|18.8|39|30|80
# 10                               Alaska|18.1|41|25|94
# 11                              Arizona|18.6|35|28|96
# 12                             Arkansas|22.4|18|26|95
# 13                             California|12|35|28|89
# 14                             Colorado|13.6|37|28|95
# 15                          Connecticut|10.8|46|36|82
# 16                             Delaware|16.2|38|30|99
# 17                 District of Columbia|5.9|34|27|100
# 18                              Florida|17.9|21|29|94
# 19                              Georgia|15.6|19|25|93
# 20                               Hawaii|17.5|54|41|87
# 21                                Idaho|15.3|36|29|98
# 22                             Illinois|12.8|36|34|96
# 23                              Indiana|14.5|25|29|95
# 24                                 Iowa|15.7|17|25|87
# 25                               Kansas|17.8|27|24|85
# 26                             Kentucky|21.4|19|23|76
# 27                            Louisiana|20.5|35|33|98
# 28                                Maine|15.1|38|30|84
# 29                             Maryland|12.5|34|32|99
# 30                         Massachusetts|8.2|23|35|80
# 31                             Michigan|14.1|24|28|77
# 32                             Minnesota|9.6|23|29|88
# 33                         Mississippi|17.6|15|31|100
# 34                             Missouri|16.1|43|34|84
# 35                              Montana|21.4|39|44|85
# 36                             Nebraska|14.9|13|35|90
# 37                               Nevada|14.7|37|32|99
# 38                        New Hampshire|11.6|35|30|83
# 39                           New Jersey|11.2|16|28|78
# 40                           New Mexico|18.4|19|27|98
# 41                             New York|12.3|32|29|80
# 42                       North Carolina|16.8|39|31|81
# 43                         North Dakota|23.9|23|42|86
# 44                                 Ohio|14.1|28|34|82
# 45                             Oklahoma|19.9|32|29|94
# 46                               Oregon|12.8|33|26|90
# 47                         Pennsylvania|18.2|50|31|88
# 48                         Rhode Island|11.1|34|38|79
# 49                       South Carolina|23.9|38|41|81
# 50                         South Dakota|19.4|31|33|86
# 51                            Tennessee|19.5|21|29|81
# 52                                Texas|19.4|40|38|87
# 53                                 Utah|11.3|43|16|96
# 54                              Vermont|13.6|30|30|95
# 55                             Virginia|12.7|19|27|88
# 56                           Washington|10.6|42|33|86
# 57                        West Virginia|23.8|34|28|87
# 58                            Wisconsin|13.8|36|33|84
# 59                              Wyoming|17.4|42|32|90
#
#                                                 State       fatl_col_bmiles  \
# 0   # This data set is modified from the original ...                  None
# 1   # and it is released under CC BY 4.0 (https://...                  None
# 2                    ##### COLUMN ABBREVIATIONS #####                  None
# 3   # drvr_fatl_col_bmiles = Number of drivers inv...                  None
# 4   # perc_fatl_speed = Percentage Of Drivers Invo...                  None
# 5   # perc_fatl_alcohol = Percentage Of Drivers In...                  None
# 6   # perc_fatl_1st_time = Percentage Of Drivers I...                  None
# 7                              ##### DATA BEGIN #####                  None
# 8                                               state  drvr_fatl_col_bmiles
# 9                                             Alabama                  18.8
# 10                                             Alaska                  18.1
# 11                                            Arizona                  18.6
# 12                                           Arkansas                  22.4
# 13                                         California                    12
# 14                                           Colorado                  13.6
# 15                                        Connecticut                  10.8
# 16                                           Delaware                  16.2
# 17                               District of Columbia                   5.9
# 18                                            Florida                  17.9
# 19                                            Georgia                  15.6
# 20                                             Hawaii                  17.5
# 21                                              Idaho                  15.3
# 22                                           Illinois                  12.8
# 23                                            Indiana                  14.5
# 24                                               Iowa                  15.7
# 25                                             Kansas                  17.8
# 26                                           Kentucky                  21.4
# 27                                          Louisiana                  20.5
# 28                                              Maine                  15.1
# 29                                           Maryland                  12.5
# 30                                      Massachusetts                   8.2
# 31                                           Michigan                  14.1
# 32                                          Minnesota                   9.6
# 33                                        Mississippi                  17.6
# 34                                           Missouri                  16.1
# 35                                            Montana                  21.4
# 36                                           Nebraska                  14.9
# 37                                             Nevada                  14.7
# 38                                      New Hampshire                  11.6
# 39                                         New Jersey                  11.2
# 40                                         New Mexico                  18.4
# 41                                           New York                  12.3
# 42                                     North Carolina                  16.8
# 43                                       North Dakota                  23.9
# 44                                               Ohio                  14.1
# 45                                           Oklahoma                  19.9
# 46                                             Oregon                  12.8
# 47                                       Pennsylvania                  18.2
# 48                                       Rhode Island                  11.1
# 49                                     South Carolina                  23.9
# 50                                       South Dakota                  19.4
# 51                                          Tennessee                  19.5
# 52                                              Texas                  19.4
# 53                                               Utah                  11.3
# 54                                            Vermont                  13.6
# 55                                           Virginia                  12.7
# 56                                         Washington                  10.6
# 57                                      West Virginia                  23.8
# 58                                          Wisconsin                  13.8
# 59                                            Wyoming                  17.4
#
#     perc_fatl_speed  perc_fatl_alcohol  perc_fatl_1st_time
# 0              None               None                None
# 1              None               None                None
# 2              None               None                None
# 3              None               None                None
# 4              None               None                None
# 5              None               None                None
# 6              None               None                None
# 7              None               None                None
# 8   perc_fatl_speed  perc_fatl_alcohol  perc_fatl_1st_time
# 9                39                 30                  80
# 10               41                 25                  94
# 11               35                 28                  96
# 12               18                 26                  95
# 13               35                 28                  89
# 14               37                 28                  95
# 15               46                 36                  82
# 16               38                 30                  99
# 17               34                 27                 100
# 18               21                 29                  94
# 19               19                 25                  93
# 20               54                 41                  87
# 21               36                 29                  98
# 22               36                 34                  96
# 23               25                 29                  95
# 24               17                 25                  87
# 25               27                 24                  85
# 26               19                 23                  76
# 27               35                 33                  98
# 28               38                 30                  84
# 29               34                 32                  99
# 30               23                 35                  80
# 31               24                 28                  77
# 32               23                 29                  88
# 33               15                 31                 100
# 34               43                 34                  84
# 35               39                 44                  85
# 36               13                 35                  90
# 37               37                 32                  99
# 38               35                 30                  83
# 39               16                 28                  78
# 40               19                 27                  98
# 41               32                 29                  80
# 42               39                 31                  81
# 43               23                 42                  86
# 44               28                 34                  82
# 45               32                 29                  94
# 46               33                 26                  90
# 47               50                 31                  88
# 48               34                 38                  79
# 49               38                 41                  81
# 50               31                 33                  86
# 51               21                 29                  81
# 52               40                 38                  87
# 53               43                 16                  96
# 54               30                 30                  95
# 55               19                 27                  88
# 56               42                 33                  86
# 57               34                 28                  87
# 58               36                 33                  84
# 59               42                 32                  90

# %%
df_2.dropna(inplace=True)

# %%
data = pd.DataFrame(columns=['State','fatl_col_bmiles','perc_fatl_speed','perc_fatl_alcohol','perc_fatl_1st_time'])
data
# Out:
# Empty DataFrame
# Columns: [State, fatl_col_bmiles, perc_fatl_speed, perc_fatl_alcohol, perc_fatl_1st_time]
# Index: []

# %%
data['State'] = df_2['State']
data['fatl_col_bmiles'] = df_2['fatl_col_bmiles']
data['perc_fatl_speed'] = df_2['perc_fatl_speed']
data['perc_fatl_alcohol'] = df_2['perc_fatl_alcohol']
data['perc_fatl_1st_time'] = df_2['perc_fatl_1st_time']

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.drop([0],inplace=True)

# %%
data.set_index('State')
# Out:
#                      fatl_col_bmiles perc_fatl_speed perc_fatl_alcohol  \
# State
# Alabama                         18.8              39                30
# Alaska                          18.1              41                25
# Arizona                         18.6              35                28
# Arkansas                        22.4              18                26
# California                        12              35                28
# Colorado                        13.6              37                28
# Connecticut                     10.8              46                36
# Delaware                        16.2              38                30
# District of Columbia             5.9              34                27
# Florida                         17.9              21                29
# Georgia                         15.6              19                25
# Hawaii                          17.5              54                41
# Idaho                           15.3              36                29
# Illinois                        12.8              36                34
# Indiana                         14.5              25                29
# Iowa                            15.7              17                25
# Kansas                          17.8              27                24
# Kentucky                        21.4              19                23
# Louisiana                       20.5              35                33
# Maine                           15.1              38                30
# Maryland                        12.5              34                32
# Massachusetts                    8.2              23                35
# Michigan                        14.1              24                28
# Minnesota                        9.6              23                29
# Mississippi                     17.6              15                31
# Missouri                        16.1              43                34
# Montana                         21.4              39                44
# Nebraska                        14.9              13                35
# Nevada                          14.7              37                32
# New Hampshire                   11.6              35                30
# New Jersey                      11.2              16                28
# New Mexico                      18.4              19                27
# New York                        12.3              32                29
# North Carolina                  16.8              39                31
# North Dakota                    23.9              23                42
# Ohio                            14.1              28                34
# Oklahoma                        19.9              32                29
# Oregon                          12.8              33                26
# Pennsylvania                    18.2              50                31
# Rhode Island                    11.1              34                38
# South Carolina                  23.9              38                41
# South Dakota                    19.4              31                33
# Tennessee                       19.5              21                29
# Texas                           19.4              40                38
# Utah                            11.3              43                16
# Vermont                         13.6              30                30
# Virginia                        12.7              19                27
# Washington                      10.6              42                33
# West Virginia                   23.8              34                28
# Wisconsin                       13.8              36                33
# Wyoming                         17.4              42                32
#
#                      perc_fatl_1st_time
# State
# Alabama                              80
# Alaska                               94
# Arizona                              96
# Arkansas                             95
# California                           89
# Colorado                             95
# Connecticut                          82
# Delaware                             99
# District of Columbia                100
# Florida                              94
# Georgia                              93
# Hawaii                               87
# Idaho                                98
# Illinois                             96
# Indiana                              95
# Iowa                                 87
# Kansas                               85
# Kentucky                             76
# Louisiana                            98
# Maine                                84
# Maryland                             99
# Massachusetts                        80
# Michigan                             77
# Minnesota                            88
# Mississippi                         100
# Missouri                             84
# Montana                              85
# Nebraska                             90
# Nevada                               99
# New Hampshire                        83
# New Jersey                           78
# New Mexico                           98
# New York                             80
# North Carolina                       81
# North Dakota                         86
# Ohio                                 82
# Oklahoma                             94
# Oregon                               90
# Pennsylvania                         88
# Rhode Island                         79
# South Carolina                       81
# South Dakota                         86
# Tennessee                            81
# Texas                                87
# Utah                                 96
# Vermont                              95
# Virginia                             88
# Washington                           86
# West Virginia                        87
# Wisconsin                            84
# Wyoming                              90

# %%
data.dtypes
# Out:
# State                 object
# fatl_col_bmiles       object
# perc_fatl_speed       object
# perc_fatl_alcohol     object
# perc_fatl_1st_time    object
# dtype: object

# %%
data['fatl_col_bmiles'] = data['fatl_col_bmiles'].astype(float)
data['perc_fatl_speed'] = data['perc_fatl_speed'].astype(float)
data['perc_fatl_alcohol'] = data['perc_fatl_alcohol'].astype(float)
data['perc_fatl_1st_time'] = data['perc_fatl_1st_time'].astype(float)

# %%
data.dtypes
# Out:
# State                  object
# fatl_col_bmiles       float64
# perc_fatl_speed       float64
# perc_fatl_alcohol     float64
# perc_fatl_1st_time    float64
# dtype: object

# %%
data.describe()
# Out:
#        fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  perc_fatl_1st_time
# count        51.000000        51.000000          51.000000            51.00000
# mean         15.790196        31.725490          30.686275            88.72549
# std           4.122002         9.633438           5.132213             6.96011
# min           5.900000        13.000000          16.000000            76.00000
# 25%          12.750000        23.000000          28.000000            83.50000
# 50%          15.600000        34.000000          30.000000            88.00000
# 75%          18.500000        38.000000          33.000000            95.00000
# max          23.900000        54.000000          44.000000           100.00000

# %% [markdown]
# Data Visualization

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data.index, y=data['fatl_col_bmiles'])
# Out:
# <AxesSubplot:ylabel='fatl_col_bmiles'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data.index, y=data['perc_fatl_speed'])
# Out:
# <AxesSubplot:ylabel='perc_fatl_speed'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data.index, y=data['perc_fatl_alcohol'])
# Out:
# <AxesSubplot:ylabel='perc_fatl_alcohol'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data.index, y=data['perc_fatl_1st_time'])
# Out:
# <AxesSubplot:ylabel='perc_fatl_1st_time'>

# %%
sns.scatterplot(data=data, x=data['fatl_col_bmiles'], y=data['perc_fatl_speed'], hue=data['perc_fatl_alcohol'])
# Out:
# <AxesSubplot:xlabel='fatl_col_bmiles', ylabel='perc_fatl_speed'>

# %% [markdown]
# Pearson Correlation

# %%
cormat = data.corr()
round(cormat,2)

sns.heatmap(cormat)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Multivariate Linear Regression

# %%
import statsmodels.api as sm


X = data[['perc_fatl_speed','perc_fatl_alcohol','perc_fatl_1st_time']]
Y = data['fatl_col_bmiles']
#X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()
summary = model.summary()
print(summary)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        fatl_col_bmiles   R-squared (uncentered):                   0.939
# Model:                            OLS   Adj. R-squared (uncentered):              0.935
# Method:                 Least Squares   F-statistic:                              247.5
# Date:                Mon, 08 Aug 2022   Prob (F-statistic):                    3.45e-29
# Time:                        21:18:13   Log-Likelihood:                         -143.31
# No. Observations:                  51   AIC:                                      292.6
# Df Residuals:                      48   BIC:                                      298.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# perc_fatl_speed       -0.0405      0.064     -0.636      0.528      -0.169       0.088
# perc_fatl_alcohol      0.2581      0.102      2.522      0.015       0.052       0.464
# perc_fatl_1st_time     0.1028      0.035      2.979      0.005       0.033       0.172
# ==============================================================================
# Omnibus:                        0.007   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.997   Jarque-Bera (JB):                0.086
# Skew:                          -0.017   Prob(JB):                        0.958
# Kurtosis:                       2.802   Cond. No.                         18.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data.reset_index(drop=True)
# Out:
#                    State  fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# 0                Alabama             18.8             39.0               30.0
# 1                 Alaska             18.1             41.0               25.0
# 2                Arizona             18.6             35.0               28.0
# 3               Arkansas             22.4             18.0               26.0
# 4             California             12.0             35.0               28.0
# 5               Colorado             13.6             37.0               28.0
# 6            Connecticut             10.8             46.0               36.0
# 7               Delaware             16.2             38.0               30.0
# 8   District of Columbia              5.9             34.0               27.0
# 9                Florida             17.9             21.0               29.0
# 10               Georgia             15.6             19.0               25.0
# 11                Hawaii             17.5             54.0               41.0
# 12                 Idaho             15.3             36.0               29.0
# 13              Illinois             12.8             36.0               34.0
# 14               Indiana             14.5             25.0               29.0
# 15                  Iowa             15.7             17.0               25.0
# 16                Kansas             17.8             27.0               24.0
# 17              Kentucky             21.4             19.0               23.0
# 18             Louisiana             20.5             35.0               33.0
# 19                 Maine             15.1             38.0               30.0
# 20              Maryland             12.5             34.0               32.0
# 21         Massachusetts              8.2             23.0               35.0
# 22              Michigan             14.1             24.0               28.0
# 23             Minnesota              9.6             23.0               29.0
# 24           Mississippi             17.6             15.0               31.0
# 25              Missouri             16.1             43.0               34.0
# 26               Montana             21.4             39.0               44.0
# 27              Nebraska             14.9             13.0               35.0
# 28                Nevada             14.7             37.0               32.0
# 29         New Hampshire             11.6             35.0               30.0
# 30            New Jersey             11.2             16.0               28.0
# 31            New Mexico             18.4             19.0               27.0
# 32              New York             12.3             32.0               29.0
# 33        North Carolina             16.8             39.0               31.0
# 34          North Dakota             23.9             23.0               42.0
# 35                  Ohio             14.1             28.0               34.0
# 36              Oklahoma             19.9             32.0               29.0
# 37                Oregon             12.8             33.0               26.0
# 38          Pennsylvania             18.2             50.0               31.0
# 39          Rhode Island             11.1             34.0               38.0
# 40        South Carolina             23.9             38.0               41.0
# 41          South Dakota             19.4             31.0               33.0
# 42             Tennessee             19.5             21.0               29.0
# 43                 Texas             19.4             40.0               38.0
# 44                  Utah             11.3             43.0               16.0
# 45               Vermont             13.6             30.0               30.0
# 46              Virginia             12.7             19.0               27.0
# 47            Washington             10.6             42.0               33.0
# 48         West Virginia             23.8             34.0               28.0
# 49             Wisconsin             13.8             36.0               33.0
# 50               Wyoming             17.4             42.0               32.0
#
#     perc_fatl_1st_time
# 0                 80.0
# 1                 94.0
# 2                 96.0
# 3                 95.0
# 4                 89.0
# 5                 95.0
# 6                 82.0
# 7                 99.0
# 8                100.0
# 9                 94.0
# 10                93.0
# 11                87.0
# 12                98.0
# 13                96.0
# 14                95.0
# 15                87.0
# 16                85.0
# 17                76.0
# 18                98.0
# 19                84.0
# 20                99.0
# 21                80.0
# 22                77.0
# 23                88.0
# 24               100.0
# 25                84.0
# 26                85.0
# 27                90.0
# 28                99.0
# 29                83.0
# 30                78.0
# 31                98.0
# 32                80.0
# 33                81.0
# 34                86.0
# 35                82.0
# 36                94.0
# 37                90.0
# 38                88.0
# 39                79.0
# 40                81.0
# 41                86.0
# 42                81.0
# 43                87.0
# 44                96.0
# 45                95.0
# 46                88.0
# 47                86.0
# 48                87.0
# 49                84.0
# 50                90.0

# %% [markdown]
# Principle Component Analysis (PCA)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
from sklearn.decomposition import PCA

# %%
X = data[['perc_fatl_speed','perc_fatl_alcohol','perc_fatl_1st_time']]
Y = data['State']

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split( X, Y, test_size=1/7.0, random_state=0)

# %%
X_train = sc.fit_transform(train_X)
X_test = sc.transform(test_X)

pca = PCA(n_components=2)
X_pca = pca.fit(X_train)

# %%
train_X = pca.transform(X_train)
test_X = pca.transform(X_test)

# %%
sns.scatterplot(data=train_X)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(train_X,train_y)
# Out:
# LogisticRegression()

# %%
Y_Pred = LR.predict(test_X)
